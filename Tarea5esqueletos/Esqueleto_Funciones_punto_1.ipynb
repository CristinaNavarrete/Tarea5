# %%
"""
Funciones para aplicar fourier a se;ales de encefalogramas
Autores:
    Cristina Navarrete Rodriguez
    Stefano Lacorazza

"""


import numpy as np


def cargarDatos(archivo):
    """
Carga la informacion del archivo con el nombre dado como parametro
Input:
- archivo: un string con el nombre del archivo que vamos a obtener
Output:
- datos: una matriz con los datos obtenidos del archivo, el tamano de la matriz dependera del archivo

"""

  
    datos = numpy.zeros(shape=(24,100))
    return datos



    
    
    
    
    

def transformada(datos, num_columna):
    """
Toma los datos obtenidos, le hace la transformada a los datos en la columna num_columna y devuelve
una matriz de amplitudes contra frecuencia
Input:
- datos: los datos
-num_columna: es el numero de la columna de los datos que se quiere transformar
Output:
transformada: Una matriz de [2,n] con n el numero de datos que es amplitud contra frecuencia
"""
    
    transformada = np.zeros(shape=(2,100))
    return transformada

def espectro(transformada):
    """
Saca el espectro de potencias de la transformada

Input:
- transformada: Una matriz de [2,n] con las amplitudes en funcion de la frecuentaca
Output:
- potencias: una matriz de  [2,n] que es el espectro de potencias de cada senal

"""
    

    return transformada

def nMaximos(potencias,m):
    """
Toma las m amplitudes maximas y vuelve 0 el resto

Input:
- potencias: Una matriz de [2,m] con las potencias de las frecuencias
- m: El numero de potencias maximas que se quiere dejar
Output:
- maximos: una matriz de  [2,n] en el cual todas las potencias son 0 excepto las m maximas

"""
    maximos=potencias
    return maximos


def graficar(potencias):
    """
Grafica el espectro de potencias

Input:
- potencias: Una matriz de [2,m] con las potencias de las frecuencias

Output:
- la grafica
"""
    return potencias

def chiCuadrado(datos, aproximacion, m):
    """
Grafica el espectro de potencias

Input:
- datos: Los datos obtenidos del archivo
- aproximada: la funcion aproximada de los datos
- m: la columna correspondiente a la aproximada
    

Output:
- chi: La chi cuadrado de las dos entradas

"""
    chi=datos
    return chi
